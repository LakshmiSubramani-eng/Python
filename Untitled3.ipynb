# %%
#pip install numpy

# %%
import numpy as np

# %%
data=[10,20,30,40,50]

# %%
np.mean(data)
# Out:
# np.float64(30.0)

# %%
np.median(data)
# Out:
# np.float64(30.0)

# %%
np.var(data)
# Out:
# np.float64(200.0)

# %%
np.std(data)
# Out:
# np.float64(14.142135623730951)
