# %%
from maths import sum,product

sum(10,20)
product(90,90)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from maths import sum,product
#       3 sum(10,20)
#       4 product(90,90)
#
# ModuleNotFoundError: No module named 'maths'
