# %%
import numpy as np

# %%
data=[89,90,78,89,67,89,45,67]

# %%
np.mean(data)
# Out:
# np.float64(76.75)

# %%
np.median(data)
# Out:
# np.float64(83.5)

# %%
np.var(data)
# Out:
# np.float64(228.1875)

# %%
np.std(data)
# Out:
# np.float64(15.105876340020794)
